# %%
import duckdb

conn = duckdb.connect(
    "sakila.duckdb"
)

conn.sql("""
SELECT table_schema, table_name
FROM information_schema.tables
ORDER BY table_schema, table_name;
""").df()
# Out:
#    table_schema           table_name
# 0       staging           _dlt_loads
# 1       staging  _dlt_pipeline_state
# 2       staging         _dlt_version
# 3       staging                actor
# 4       staging              address
# 5       staging             category
# 6       staging                 city
# 7       staging              country
# 8       staging             customer
# 9       staging                 film
# 10      staging           film_actor
# 11      staging        film_category
# 12      staging            inventory
# 13      staging             language
# 14      staging              payment
# 15      staging               rental
# 16      staging                staff
# 17      staging                store
